# %%
# Módulo/bibliotecas utilizadas
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
# Define caminhos de input e output
URL = ''   # url de dados (input)
IMG_PATH  = '../img/'                  # diretório de imagens (output)

# %%
# Cria séries de dados sintéticos
t = np.linspace(0,2*2*np.pi,200)
y1 = np.cos(3*np.pi*t/10) + np.sin(5*t) + np.sin(8*t) + np.sin(12*t) + 0.2*np.random.randn(len(t))
y2 = np.cos(3*np.pi*t/10) + np.sin(5*t) + np.sin(8*t) + 0.2*np.random.randn(len(t))

# %%
plt.plot(t,y1)
plt.plot(t,y2)
plt.ylabel('y1, y2')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
# Calcula correlação entre série y1 e y2
correlacao = y1.T@y2 / np.sqrt( (y1.T@y1) * (y2.T@y2) )
correlacao
# Out:
# 0.8450657755003528

# %%
# Recalcula a corelação utilizando uma built-in function
np.corrcoef(y1,y2)[0,1]
# Out:
# 0.8448483101580798

# %%
# Cálculo correlação entre as séries
ph = -np.pi/2
y3 = np.cos(4*np.pi*t/10) + 0.2*np.random.randn(len(t))
y4 = np.cos(4*np.pi*t/10+ph) + 0.2*np.random.randn(len(t))

# %%
plt.plot(t,y3)
plt.plot(t,y4)
plt.ylabel('y3, y4')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
# Calcula correlação entre série y1 e y2
correlacao = y3.T@y4 / np.sqrt( (y3.T@y3) * (y4.T@y4) )
correlacao
# Out:
# 0.032481935310333394

# %%
def calcula_correlacao(serie1,serie2):
    corr = serie1.T@serie2 / np.sqrt( (serie1.T@serie1) * (serie2.T@serie2) )
    return corr

# %%
calcula_correlacao(y1,y2), calcula_correlacao(y3,y4)
# Out:
# (0.8450657755003528, 0.032481935310333394)

# %%
lags = np.arange(-6,6,0.1)
correlations = np.zeros(len(lags))

# for k in range(len(lags)):
# what to do with boundaries

# %%
# Out:
# 199

# %%
n = len(t)
lags = np.arange(-n+1,n)*t[1]
corr_y2_y3 = np.correlate(y2,y3, mode='full')
nmax = corr_y2_y3.argmax()
# corr_y2_y3 /= corr_y2_y3[nmax]
corr_y2_y3[nmax]
# Out:
# 56.48285329281842

# %%
plt.plot(lags,corr_y2_y3)
plt.xlim(-np.pi,np.pi)
# Out:
# (-3.141592653589793, 3.141592653589793)
